# %% [markdown]
# ## Base de datos 2

# %%
# Descargar libreria
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
OCDE=pd.read_csv("BLI.csv")

OCDE.head(50)
# Out:
#    LOCATION          Country INDICATOR  \
# 0       AUS        Australia   JE_LMIS
# 1       AUT          Austria   JE_LMIS
# 2       BEL          Belgium   JE_LMIS
# 3       CAN           Canada   JE_LMIS
# 4       CZE   Czech Republic   JE_LMIS
# 5       DNK          Denmark   JE_LMIS
# 6       FIN          Finland   JE_LMIS
# 7       FRA           France   JE_LMIS
# 8       DEU          Germany   JE_LMIS
# 9       GRC           Greece   JE_LMIS
# 10      HUN          Hungary   JE_LMIS
# 11      ISL          Iceland   JE_LMIS
# 12      IRL          Ireland   JE_LMIS
# 13      ITA            Italy   JE_LMIS
# 14      JPN            Japan   JE_LMIS
# 15      KOR            Korea   JE_LMIS
# 16      LUX       Luxembourg   JE_LMIS
# 17      MEX           Mexico   JE_LMIS
# 18      NLD      Netherlands   JE_LMIS
# 19      NZL      New Zealand   JE_LMIS
# 20      NOR           Norway   JE_LMIS
# 21      POL           Poland   JE_LMIS
# 22      PRT         Portugal   JE_LMIS
# ...

# %%
OCDE["Indicator"].unique()
# Out:
# array(['Labour market insecurity',
#        'Stakeholder engagement for developing regulations',
#        'Feeling safe walking alone at night',
#        'Dwellings without basic facilities', 'Housing expenditure',
#        'Rooms per person', 'Household net adjusted disposable income',
#        'Household net financial wealth', 'Employment rate',
#        'Long-term unemployment rate', 'Personal earnings',
#        'Quality of support network', 'Educational attainment',
#        'Student skills', 'Years in education', 'Air pollution',
#        'Water quality', 'Voter turnout', 'Life expectancy',
#        'Self-reported health', 'Life satisfaction', 'Homicide rate',
#        'Employees working very long hours',
#        'Time devoted to leisure and personal care'], dtype=object)

# %%
len(OCDE["Indicator"].unique())
#Cuántos indicadores hay
# Out:
# 24

# %%
#Cuántos paises son
len(OCDE["Country"].unique())
# Out:
# 39

# %%
OCDE["Indicator"].unique()
# Out:
# array(['Labour market insecurity',
#        'Stakeholder engagement for developing regulations',
#        'Feeling safe walking alone at night',
#        'Dwellings without basic facilities', 'Housing expenditure',
#        'Rooms per person', 'Household net adjusted disposable income',
#        'Household net financial wealth', 'Employment rate',
#        'Long-term unemployment rate', 'Personal earnings',
#        'Quality of support network', 'Educational attainment',
#        'Student skills', 'Years in education', 'Air pollution',
#        'Water quality', 'Voter turnout', 'Life expectancy',
#        'Self-reported health', 'Life satisfaction', 'Homicide rate',
#        'Employees working very long hours',
#        'Time devoted to leisure and personal care'], dtype=object)

# %%
#Crear una nueva copia, para depurar datos
OCDE2=OCDE.drop(["INDICATOR","MEASURE","INEQUALITY","Unit Code","PowerCode Code","Reference Period Code","Flag Codes"],axis=1)

# %%
# ver datos datos en una sola tira 
# ver lista completa
pd.DataFrame(OCDE2)
# Out:
#      LOCATION          Country INDICATOR  \
# 0         AUS        Australia   JE_LMIS
# 1         AUT          Austria   JE_LMIS
# 2         BEL          Belgium   JE_LMIS
# 3         CAN           Canada   JE_LMIS
# 4         CZE   Czech Republic   JE_LMIS
# 5         DNK          Denmark   JE_LMIS
# 6         FIN          Finland   JE_LMIS
# 7         FRA           France   JE_LMIS
# 8         DEU          Germany   JE_LMIS
# 9         GRC           Greece   JE_LMIS
# 10        HUN          Hungary   JE_LMIS
# 11        ISL          Iceland   JE_LMIS
# 12        IRL          Ireland   JE_LMIS
# 13        ITA            Italy   JE_LMIS
# 14        JPN            Japan   JE_LMIS
# 15        KOR            Korea   JE_LMIS
# 16        LUX       Luxembourg   JE_LMIS
# 17        MEX           Mexico   JE_LMIS
# 18        NLD      Netherlands   JE_LMIS
# 19        NZL      New Zealand   JE_LMIS
# 20        NOR           Norway   JE_LMIS
# 21        POL           Poland   JE_LMIS
# ...

# %%
OCDE2=OCDE.set_index("Indicator")

# %%
OCDE2.loc[("Labour market insecurity")]
# Out:
#                          LOCATION          Country INDICATOR MEASURE Measure  \
# Indicator
# Labour market insecurity      AUS        Australia   JE_LMIS       L   Value
# Labour market insecurity      AUT          Austria   JE_LMIS       L   Value
# Labour market insecurity      BEL          Belgium   JE_LMIS       L   Value
# Labour market insecurity      CAN           Canada   JE_LMIS       L   Value
# Labour market insecurity      CZE   Czech Republic   JE_LMIS       L   Value
# Labour market insecurity      DNK          Denmark   JE_LMIS       L   Value
# Labour market insecurity      FIN          Finland   JE_LMIS       L   Value
# Labour market insecurity      FRA           France   JE_LMIS       L   Value
# Labour market insecurity      DEU          Germany   JE_LMIS       L   Value
# Labour market insecurity      GRC           Greece   JE_LMIS       L   Value
# Labour market insecurity      HUN          Hungary   JE_LMIS       L   Value
# ...

# %%
OCDE2.loc[("Feeling safe walking alone at night")]
# Out:
#                                     LOCATION          Country  INDICATOR  \
# Indicator
# Feeling safe walking alone at night      AUS        Australia  PS_FSAFEN
# Feeling safe walking alone at night      AUT          Austria  PS_FSAFEN
# Feeling safe walking alone at night      BEL          Belgium  PS_FSAFEN
# Feeling safe walking alone at night      CAN           Canada  PS_FSAFEN
# Feeling safe walking alone at night      CZE   Czech Republic  PS_FSAFEN
# Feeling safe walking alone at night      DNK          Denmark  PS_FSAFEN
# Feeling safe walking alone at night      FIN          Finland  PS_FSAFEN
# Feeling safe walking alone at night      FRA           France  PS_FSAFEN
# Feeling safe walking alone at night      DEU          Germany  PS_FSAFEN
# Feeling safe walking alone at night      GRC           Greece  PS_FSAFEN
# Feeling safe walking alone at night      HUN          Hungary  PS_FSAFEN
# Feeling safe walking alone at night      ISL          Iceland  PS_FSAFEN
# ...

# %%
# Datos de inseguridad=OCDE2[OCDE2["Indicator"]=="Labour market insecurity"]
# Datos de inseguridad=OCDE2[OCDE2["Inequality"]=="Total"]

# Datos de inseguridad
# Measure
